# %%
pip install googletrans==4.0.0-rc1
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.8.30)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2024.11.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 4.6 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 6.3 MB/s eta 0:00:00
# Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.0 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.2 MB/s eta 0:00:00
# Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.8 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading hstspreload-2024.11.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 8.6 MB/s eta 0:00:00
# Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 2.0 MB/s eta 0:00:00
# Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=fc138f61a3192b8ffd05c1dd6c6218b0d3b5d6f87765a7870cb79b259c41af72
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.6
#     Uninstalling httpcore-1.0.6:
#       Successfully uninstalled httpcore-1.0.6
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.2
#     Uninstalling httpx-0.27.2:
#       Successfully uninstalled httpx-0.27.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langsmith 0.1.137 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# openai 1.52.2 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.11.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %% [markdown]
# Exploratory data analysis

# %%
pip install opencage
# Out:
# Collecting opencage
#   Downloading opencage-3.0.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: Requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from opencage) (2.32.3)
# Collecting backoff>=2.2.1 (from opencage)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: tqdm>=4.66.4 in /usr/local/lib/python3.10/dist-packages (from opencage) (4.66.6)
# Requirement already satisfied: certifi>=2024.07.04 in /usr/local/lib/python3.10/dist-packages (from opencage) (2024.8.30)
# Requirement already satisfied: aiohttp>=3.10.5 in /usr/local/lib/python3.10/dist-packages (from opencage) (3.10.10)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.5->opencage) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.5->opencage) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.5->opencage) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.5->opencage) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.5->opencage) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.5->opencage) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.5->opencage) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from Requests>=2.31.0->opencage) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from Requests>=2.31.0->opencage) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from Requests>=2.31.0->opencage) (2.2.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp>=3.10.5->opencage) (4.12.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp>=3.10.5->opencage) (0.2.0)
# Downloading opencage-3.0.2-py3-none-any.whl (21 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Installing collected packages: backoff, opencage
# Successfully installed backoff-2.2.1 opencage-3.0.2

# %%
import pandas as pd
from googletrans import Translator
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn. preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
import pandas as pd

# Load the Excel file
data = pd.read_excel("/content/PEFR Dataset.xlsx")

# %%
data.head()
# Out:
#        ID     BCODE       UID1 UID2  Age Sex Smoke  Smoke_amount  Height  \
# 0  SB-001  14631875  BC4386476  NaN   43   M    NS             0     156
# 1  SB-002  14010074  BC3298156  NaN   66   M    NS             0     163
# 2  SB-003  14221420  BC4165314  NaN   61   M    ES            20     173
# 3  SB-004  14010592  BC4201070  NaN   49   M    NS             0     142
# 4  SB-005  14010759  BC4212692  NaN   53   M    NS             0     156
#
#    Weight        BMI       BSA occupation                         address
# 0      76  31.229454  1.814754         주부            경기도 시흥시 마유로 443번길 1
# 1      58  21.829952  1.620528        제조업   경기 부천시 원미구 중동 무지개마을 1201-1602
# 2      67  22.386314  1.794358         타일                 인천시 부평구 수변로 333
# 3      51  25.292601  1.418332         주부                인천 서구 연희동 799-14
# 4      70  28.763971  1.741647        무응답  경기 부천시 원미구 상3동 라일락마을 2333-1503

# %%
data.columns
# Out:
# Index(['ID', 'BCODE', 'UID1', 'UID2', 'Age', 'Sex', 'Smoke', 'Smoke_amount',
#        'Height', 'Weight', 'BMI', 'BSA', 'occupation', 'address'],
#       dtype='object')

# %%
translator= Translator()

# %%
data['address_english'] = data['address'].apply(lambda x: translator.translate(x, src='ko', dest='en').text)

# %%
data['occupation_english'] = data['occupation'].apply(lambda x: translator.translate(x, src='ko', dest='en').text)

# %%
data.head()
# Out:
#        ID     BCODE       UID1 UID2  Age Sex Smoke  Smoke_amount  Height  \
# 0  SB-001  14631875  BC4386476  NaN   43   M    NS             0     156
# 1  SB-002  14010074  BC3298156  NaN   66   M    NS             0     163
# 2  SB-003  14221420  BC4165314  NaN   61   M    ES            20     173
# 3  SB-004  14010592  BC4201070  NaN   49   M    NS             0     142
# 4  SB-005  14010759  BC4212692  NaN   53   M    NS             0     156
#
#    Weight        BMI       BSA occupation                         address  \
# 0      76  31.229454  1.814754         주부            경기도 시흥시 마유로 443번길 1
# 1      58  21.829952  1.620528        제조업   경기 부천시 원미구 중동 무지개마을 1201-1602
# 2      67  22.386314  1.794358         타일                 인천시 부평구 수변로 333
# 3      51  25.292601  1.418332         주부                인천 서구 연희동 799-14
# 4      70  28.763971  1.741647        무응답  경기 부천시 원미구 상3동 라일락마을 2333-1503
#
#                                      address_english      occupation_english
# 0  1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...               housewife
# 1  1201-1602, Rainbow Village in Middle East, Won...  Manufacturing industry
# 2                         333, Bupyeong -gu, Incheon                    tile
# 3              799-14, Yeonhui-dong, Seo-gu, Incheon               housewife
# 4  2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...             No response

# %%
data.columns
# Out:
# Index(['ID', 'BCODE', 'UID1', 'UID2', 'Age', 'Sex', 'Smoke', 'Smoke_amount',
#        'Height', 'Weight', 'BMI', 'BSA', 'occupation', 'address',
#        'address_english', 'occupation_english'],
#       dtype='object')

# %%
columns = list(data.columns)


# Remove 'occupation_english' from its current position
columns.remove('occupation_english')

# Find the index of 'occupation' and insert 'occupation_english' next to it
occupation_index = columns.index('occupation')
columns.insert(occupation_index + 1, 'occupation_english')

# Reorder the DataFrame using the new column order
data = data[columns]

# %%
# Display the updated DataFrame
data.head()
# Out:
#        ID     BCODE       UID1 UID2  Age Sex Smoke  Smoke_amount  Height  \
# 0  SB-001  14631875  BC4386476  NaN   43   M    NS             0     156
# 1  SB-002  14010074  BC3298156  NaN   66   M    NS             0     163
# 2  SB-003  14221420  BC4165314  NaN   61   M    ES            20     173
# 3  SB-004  14010592  BC4201070  NaN   49   M    NS             0     142
# 4  SB-005  14010759  BC4212692  NaN   53   M    NS             0     156
#
#    Weight        BMI       BSA occupation      occupation_english  \
# 0      76  31.229454  1.814754         주부               housewife
# 1      58  21.829952  1.620528        제조업  Manufacturing industry
# 2      67  22.386314  1.794358         타일                    tile
# 3      51  25.292601  1.418332         주부               housewife
# 4      70  28.763971  1.741647        무응답             No response
#
#                           address  \
# 0            경기도 시흥시 마유로 443번길 1
# 1   경기 부천시 원미구 중동 무지개마을 1201-1602
# 2                 인천시 부평구 수변로 333
# 3                인천 서구 연희동 799-14
# 4  경기 부천시 원미구 상3동 라일락마을 2333-1503
#
#                                      address_english
# 0  1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...
# 1  1201-1602, Rainbow Village in Middle East, Won...
# 2                         333, Bupyeong -gu, Incheon
# 3              799-14, Yeonhui-dong, Seo-gu, Incheon
# 4  2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...

# %%
data.tail()
# Out:
#          ID     BCODE       UID1 UID2  Age Sex Smoke  Smoke_amount  Height  \
# 109  SB-135  14000819  BC3296833  NaN   79   M    NS             0     163
# 110  SB-137  14000774  BC3300701  NaN   76   F    NS             0     160
# 111  SB-139  14000670  BC3334855  NaN   50   F    ES            20     162
# 112  SB-140  14000334  BC3309595  NaN   69   F    ES            15     170
# 113  SB-141  14000223  BC3294749  NaN   71   F    NS             0     162
#
#      Weight        BMI       BSA occupation     occupation_english  \
# 109      67  25.217359  1.741726         무직           inoccupation
# 110      66  25.781250  1.712698         주부              housewife
# 111      64  24.386526  1.697056        건설업  Construction industry
# 112      72  24.913495  1.843909        건설업  Construction industry
# 113      73  27.815882  1.812457         기타                    etc
#
#                   address                                    address_english
# 109     부천시 원미구 도당동 137-4           137-4, Dodang-dong, Wonmi-gu, Bucheon-si
# 110        경기도 부천시 부흥로 71         71, revival -ro, Bucheon -si, Gyeonggi -do
# 111  부천시 원미구 중2동 그린타운 한신A                                          Hanshin A
# 112      부천시 원미구 중3동 중흥마을  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...
# 113      부천시 오정구 여월동 8-54            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si

# %%
data.dtypes
# Out:
# ID                     object
# BCODE                  object
# UID1                   object
# UID2                   object
# Age                     int64
# Sex                    object
# Smoke                  object
# Smoke_amount            int64
# Height                  int64
# Weight                  int64
# BMI                   float64
# BSA                   float64
# occupation             object
# occupation_english     object
# address                object
# address_english        object
# dtype: object

# %%
data.describe()
# Out:
#               Age  Smoke_amount      Height      Weight         BMI  \
# count  114.000000    114.000000  114.000000  114.000000  114.000000
# mean    64.385965      4.421053  161.157895   61.456140   23.618534
# std     12.636868     10.222217    7.995108    9.355459    2.886096
# min     30.000000      0.000000  142.000000   40.000000   16.866251
# 25%     57.000000      0.000000  156.000000   54.000000   21.734046
# 50%     65.000000      0.000000  161.500000   61.000000   23.624884
# 75%     72.000000      0.750000  166.000000   68.000000   25.276806
# max     90.000000     60.000000  187.000000   83.000000   32.830980
#
#               BSA
# count  114.000000
# mean     1.655250
# std      0.155292
# min      1.299573
# 25%      1.535278
# 50%      1.647388
# 75%      1.777755
# max      1.990812

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  114 non-null    object
#  1   BCODE               114 non-null    object
#  2   UID1                114 non-null    object
#  3   UID2                5 non-null      object
#  4   Age                 114 non-null    int64
#  5   Sex                 114 non-null    object
#  6   Smoke               114 non-null    object
#  7   Smoke_amount        114 non-null    int64
#  8   Height              114 non-null    int64
#  9   Weight              114 non-null    int64
#  10  BMI                 114 non-null    float64
#  11  BSA                 114 non-null    float64
#  12  occupation          114 non-null    object
#  13  occupation_english  114 non-null    object
#  14  address             114 non-null    object
#  15  address_english     114 non-null    object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 14.4+ KB

# %%
data.isnull().sum()
# Out:
# ID                      0
# BCODE                   0
# UID1                    0
# UID2                  109
# Age                     0
# Sex                     0
# Smoke                   0
# Smoke_amount            0
# Height                  0
# Weight                  0
# BMI                     0
# BSA                     0
# occupation              0
# occupation_english      0
# address                 0
# address_english         0
# dtype: int64

# %%
data = data.drop("UID2", axis=1)

# %%
data
# Out:
#          ID     BCODE       UID1  Age Sex Smoke  Smoke_amount  Height  Weight  \
# 0    SB-001  14631875  BC4386476   43   M    NS             0     156      76
# 1    SB-002  14010074  BC3298156   66   M    NS             0     163      58
# 2    SB-003  14221420  BC4165314   61   M    ES            20     173      67
# 3    SB-004  14010592  BC4201070   49   M    NS             0     142      51
# 4    SB-005  14010759  BC4212692   53   M    NS             0     156      70
# ..      ...       ...        ...  ...  ..   ...           ...     ...     ...
# 109  SB-135  14000819  BC3296833   79   M    NS             0     163      67
# 110  SB-137  14000774  BC3300701   76   F    NS             0     160      66
# 111  SB-139  14000670  BC3334855   50   F    ES            20     162      64
# 112  SB-140  14000334  BC3309595   69   F    ES            15     170      72
# 113  SB-141  14000223  BC3294749   71   F    NS             0     162      73
#
#            BMI       BSA occupation      occupation_english  \
# 0    31.229454  1.814754         주부               housewife
# 1    21.829952  1.620528        제조업  Manufacturing industry
# 2    22.386314  1.794358         타일                    tile
# 3    25.292601  1.418332         주부               housewife
# 4    28.763971  1.741647        무응답             No response
# ..         ...       ...        ...                     ...
# 109  25.217359  1.741726         무직            inoccupation
# 110  25.781250  1.712698         주부               housewife
# 111  24.386526  1.697056        건설업   Construction industry
# 112  24.913495  1.843909        건설업   Construction industry
# 113  27.815882  1.812457         기타                     etc
#
#                             address  \
# 0              경기도 시흥시 마유로 443번길 1
# 1     경기 부천시 원미구 중동 무지개마을 1201-1602
# 2                   인천시 부평구 수변로 333
# 3                  인천 서구 연희동 799-14
# 4    경기 부천시 원미구 상3동 라일락마을 2333-1503
# ..                              ...
# 109               부천시 원미구 도당동 137-4
# 110                  경기도 부천시 부흥로 71
# 111            부천시 원미구 중2동 그린타운 한신A
# 112                부천시 원미구 중3동 중흥마을
# 113                부천시 오정구 여월동 8-54
#
#                                        address_english
# 0    1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...
# 1    1201-1602, Rainbow Village in Middle East, Won...
# 2                           333, Bupyeong -gu, Incheon
# 3                799-14, Yeonhui-dong, Seo-gu, Incheon
# 4    2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...
# ..                                                 ...
# 109           137-4, Dodang-dong, Wonmi-gu, Bucheon-si
# 110         71, revival -ro, Bucheon -si, Gyeonggi -do
# 111                                          Hanshin A
# 112  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...
# 113            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si
#
# [114 rows x 15 columns]

# %%
from google.colab import files
data.to_csv('data.csv', encoding = 'utf-8-sig')
files.download('data.csv')

# %%
df=pd.read_csv("/content/data.csv")

# %%
df
# Out:
#      Unnamed: 0      ID     BCODE       UID1  Age Sex Smoke  Smoke_amount  \
# 0             0  SB-001  14631875  BC4386476   43   M    NS             0
# 1             1  SB-002  14010074  BC3298156   66   M    NS             0
# 2             2  SB-003  14221420  BC4165314   61   M    ES            20
# 3             3  SB-004  14010592  BC4201070   49   M    NS             0
# 4             4  SB-005  14010759  BC4212692   53   M    NS             0
# ..          ...     ...       ...        ...  ...  ..   ...           ...
# 109         109  SB-135  14000819  BC3296833   79   M    NS             0
# 110         110  SB-137  14000774  BC3300701   76   F    NS             0
# 111         111  SB-139  14000670  BC3334855   50   F    ES            20
# 112         112  SB-140  14000334  BC3309595   69   F    ES            15
# 113         113  SB-141  14000223  BC3294749   71   F    NS             0
#
#      Height  Weight        BMI       BSA occupation      occupation_english  \
# 0       156      76  31.229454  1.814754         주부               housewife
# 1       163      58  21.829952  1.620528        제조업  Manufacturing industry
# 2       173      67  22.386314  1.794358         타일                    tile
# 3       142      51  25.292601  1.418332         주부               housewife
# 4       156      70  28.763971  1.741647        무응답             No response
# ..      ...     ...        ...       ...        ...                     ...
# 109     163      67  25.217359  1.741726         무직            inoccupation
# 110     160      66  25.781250  1.712698         주부               housewife
# 111     162      64  24.386526  1.697056        건설업   Construction industry
# 112     170      72  24.913495  1.843909        건설업   Construction industry
# 113     162      73  27.815882  1.812457         기타                     etc
#
#                             address  \
# 0              경기도 시흥시 마유로 443번길 1
# 1     경기 부천시 원미구 중동 무지개마을 1201-1602
# 2                   인천시 부평구 수변로 333
# 3                  인천 서구 연희동 799-14
# 4    경기 부천시 원미구 상3동 라일락마을 2333-1503
# ..                              ...
# 109               부천시 원미구 도당동 137-4
# 110                  경기도 부천시 부흥로 71
# 111            부천시 원미구 중2동 그린타운 한신A
# 112                부천시 원미구 중3동 중흥마을
# 113                부천시 오정구 여월동 8-54
#
#                                        address_english
# 0    1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...
# 1    1201-1602, Rainbow Village in Middle East, Won...
# 2                           333, Bupyeong -gu, Incheon
# 3                799-14, Yeonhui-dong, Seo-gu, Incheon
# 4    2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...
# ..                                                 ...
# 109           137-4, Dodang-dong, Wonmi-gu, Bucheon-si
# 110         71, revival -ro, Bucheon -si, Gyeonggi -do
# 111                                          Hanshin A
# 112  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...
# 113            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si
#
# [114 rows x 16 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0         Age  Smoke_amount      Height      Weight  \
# count  114.000000  114.000000    114.000000  114.000000  114.000000
# mean    56.500000   64.385965      4.421053  161.157895   61.456140
# std     33.052988   12.636868     10.222217    7.995108    9.355459
# min      0.000000   30.000000      0.000000  142.000000   40.000000
# 25%     28.250000   57.000000      0.000000  156.000000   54.000000
# 50%     56.500000   65.000000      0.000000  161.500000   61.000000
# 75%     84.750000   72.000000      0.750000  166.000000   68.000000
# max    113.000000   90.000000     60.000000  187.000000   83.000000
#
#               BMI         BSA
# count  114.000000  114.000000
# mean    23.618534    1.655250
# std      2.886096    0.155292
# min     16.866251    1.299573
# 25%     21.734046    1.535278
# 50%     23.624884    1.647388
# 75%     25.276806    1.777755
# max     32.830980    1.990812

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          114 non-null    int64
#  1   ID                  114 non-null    object
#  2   BCODE               114 non-null    object
#  3   UID1                114 non-null    object
#  4   Age                 114 non-null    int64
#  5   Sex                 114 non-null    object
#  6   Smoke               114 non-null    object
#  7   Smoke_amount        114 non-null    int64
#  8   Height              114 non-null    int64
#  9   Weight              114 non-null    int64
#  10  BMI                 114 non-null    float64
#  11  BSA                 114 non-null    float64
#  12  occupation          114 non-null    object
#  13  occupation_english  114 non-null    object
#  14  address             114 non-null    object
#  15  address_english     114 non-null    object
# dtypes: float64(2), int64(5), object(9)
# memory usage: 14.4+ KB

# %%
encode= LabelEncoder()

# %%
df['Sex']=encode.fit_transform(df['Sex'])

# %%
df['Smoke']=encode.fit_transform(df['Smoke'])

# %%
df
# Out:
#      Unnamed: 0      ID     BCODE       UID1       Age  Sex  Smoke  \
# 0             0  SB-001  14631875  BC4386476 -1.699819    1      1
# 1             1  SB-002  14010074  BC3298156  0.128288    1      1
# 2             2  SB-003  14221420  BC4165314 -0.269126    1      0
# 3             3  SB-004  14010592  BC4201070 -1.222921    1      1
# 4             4  SB-005  14010759  BC4212692 -0.904990    1      1
# ..          ...     ...       ...        ...       ...  ...    ...
# 109         109  SB-135  14000819  BC3296833  1.161566    1      1
# 110         110  SB-137  14000774  BC3300701  0.923117    0      1
# 111         111  SB-139  14000670  BC3334855 -1.143438    0      0
# 112         112  SB-140  14000334  BC3309595  0.366737    0      0
# 113         113  SB-141  14000223  BC3294749  0.525703    0      1
#
#      Smoke_amount    Height    Weight       BMI       BSA occupation  \
# 0       -0.434404 -0.647980  1.561449  2.648742  1.031656         주부
# 1       -0.434404  0.231421 -0.371056 -0.622460 -0.224579        제조업
# 2        1.530757  1.487708  0.595196 -0.428835  0.899738         타일
# 3       -0.434404 -2.406781 -1.122586  0.582606 -1.532359         주부
# 4       -0.434404 -0.647980  0.917281  1.790708  0.558804        무응답
# ..            ...       ...       ...       ...       ...        ...
# 109     -0.434404  0.231421  0.595196  0.556421  0.559320         무직
# 110     -0.434404 -0.145465  0.487835  0.752665  0.371564         주부
# 111      1.530757  0.105793  0.273112  0.267276  0.270397        건설업
# 112      1.039467  1.110822  1.132003  0.450670  1.220225        건설업
# 113     -0.434404  0.105793  1.239365  1.460755  1.016796         기타
#
#          occupation_english                         address  \
# 0                 housewife            경기도 시흥시 마유로 443번길 1
# 1    Manufacturing industry   경기 부천시 원미구 중동 무지개마을 1201-1602
# 2                      tile                 인천시 부평구 수변로 333
# 3                 housewife                인천 서구 연희동 799-14
# 4               No response  경기 부천시 원미구 상3동 라일락마을 2333-1503
# ..                      ...                             ...
# 109            inoccupation               부천시 원미구 도당동 137-4
# 110               housewife                  경기도 부천시 부흥로 71
# 111   Construction industry            부천시 원미구 중2동 그린타운 한신A
# 112   Construction industry                부천시 원미구 중3동 중흥마을
# 113                     etc                부천시 오정구 여월동 8-54
#
#                                        address_english Age_group BMI_category  \
# 0    1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...       NaN  Underweight
# 1    1201-1602, Rainbow Village in Middle East, Won...       <18          NaN
# 2                           333, Bupyeong -gu, Incheon       NaN          NaN
# 3                799-14, Yeonhui-dong, Seo-gu, Incheon       NaN  Underweight
# 4    2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...       NaN  Underweight
# ..                                                 ...       ...          ...
# 109           137-4, Dodang-dong, Wonmi-gu, Bucheon-si       <18  Underweight
# 110         71, revival -ro, Bucheon -si, Gyeonggi -do       <18  Underweight
# 111                                          Hanshin A       NaN  Underweight
# 112  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...       <18  Underweight
# 113            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si       <18  Underweight
#
#     Smoking_intensity
# 0                 NaN
# 1                 NaN
# 2          Non-smoker
# 3                 NaN
# 4                 NaN
# ..                ...
# 109               NaN
# 110               NaN
# 111        Non-smoker
# 112        Non-smoker
# 113               NaN
#
# [114 rows x 19 columns]

# %%
df
# Out:
#      Unnamed: 0      ID     BCODE       UID1       Age  Sex  Smoke  \
# 0             0  SB-001  14631875  BC4386476 -1.699819    1      1
# 1             1  SB-002  14010074  BC3298156  0.128288    1      1
# 2             2  SB-003  14221420  BC4165314 -0.269126    1      0
# 3             3  SB-004  14010592  BC4201070 -1.222921    1      1
# 4             4  SB-005  14010759  BC4212692 -0.904990    1      1
# ..          ...     ...       ...        ...       ...  ...    ...
# 109         109  SB-135  14000819  BC3296833  1.161566    1      1
# 110         110  SB-137  14000774  BC3300701  0.923117    0      1
# 111         111  SB-139  14000670  BC3334855 -1.143438    0      0
# 112         112  SB-140  14000334  BC3309595  0.366737    0      0
# 113         113  SB-141  14000223  BC3294749  0.525703    0      1
#
#      Smoke_amount    Height    Weight       BMI       BSA occupation  \
# 0       -0.434404 -0.647980  1.561449  2.648742  1.031656         주부
# 1       -0.434404  0.231421 -0.371056 -0.622460 -0.224579        제조업
# 2        1.530757  1.487708  0.595196 -0.428835  0.899738         타일
# 3       -0.434404 -2.406781 -1.122586  0.582606 -1.532359         주부
# 4       -0.434404 -0.647980  0.917281  1.790708  0.558804        무응답
# ..            ...       ...       ...       ...       ...        ...
# 109     -0.434404  0.231421  0.595196  0.556421  0.559320         무직
# 110     -0.434404 -0.145465  0.487835  0.752665  0.371564         주부
# 111      1.530757  0.105793  0.273112  0.267276  0.270397        건설업
# 112      1.039467  1.110822  1.132003  0.450670  1.220225        건설업
# 113     -0.434404  0.105793  1.239365  1.460755  1.016796         기타
#
#          occupation_english                         address  \
# 0                 housewife            경기도 시흥시 마유로 443번길 1
# 1    Manufacturing industry   경기 부천시 원미구 중동 무지개마을 1201-1602
# 2                      tile                 인천시 부평구 수변로 333
# 3                 housewife                인천 서구 연희동 799-14
# 4               No response  경기 부천시 원미구 상3동 라일락마을 2333-1503
# ..                      ...                             ...
# 109            inoccupation               부천시 원미구 도당동 137-4
# 110               housewife                  경기도 부천시 부흥로 71
# 111   Construction industry            부천시 원미구 중2동 그린타운 한신A
# 112   Construction industry                부천시 원미구 중3동 중흥마을
# 113                     etc                부천시 오정구 여월동 8-54
#
#                                        address_english Age_group BMI_category  \
# 0    1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...       NaN  Underweight
# 1    1201-1602, Rainbow Village in Middle East, Won...       <18          NaN
# 2                           333, Bupyeong -gu, Incheon       NaN          NaN
# 3                799-14, Yeonhui-dong, Seo-gu, Incheon       NaN  Underweight
# 4    2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...       NaN  Underweight
# ..                                                 ...       ...          ...
# 109           137-4, Dodang-dong, Wonmi-gu, Bucheon-si       <18  Underweight
# 110         71, revival -ro, Bucheon -si, Gyeonggi -do       <18  Underweight
# 111                                          Hanshin A       NaN  Underweight
# 112  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...       <18  Underweight
# 113            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si       <18  Underweight
#
#     Smoking_intensity
# 0                 NaN
# 1                 NaN
# 2          Non-smoker
# 3                 NaN
# 4                 NaN
# ..                ...
# 109               NaN
# 110               NaN
# 111        Non-smoker
# 112        Non-smoker
# 113               NaN
#
# [114 rows x 19 columns]

# %%
# Example: Creating Smoking Intensity feature
df['Smoking_intensity'] = pd.cut(df['Smoke_amount'], bins=[0, 5, 20, 100], labels=['Non-smoker', 'Light smoker', 'Heavy smoker'])

# %%
# Example: Binning Age into groups
df['Age_group'] = pd.cut(df['Age'], bins=[0, 18, 30, 45, 60, 100], labels=['<18', '18-30', '30-45', '45-60', '60+'])

# Example: Binning BMI into categories
df['BMI_category'] = pd.cut(df['BMI'], bins=[0, 18.5, 24.9, 29.9, 100], labels=['Underweight', 'Normal', 'Overweight', 'Obese'])

# %%
from google.colab import files
df.to_csv('PEFR.csv', encoding = 'utf-8-sig')
files.download('PEFR.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      ID     BCODE       UID1       Age  Sex  Smoke  \
# 0           0  SB-001  14631875  BC4386476 -1.699819    1      1
# 1           1  SB-002  14010074  BC3298156  0.128288    1      1
# 2           2  SB-003  14221420  BC4165314 -0.269126    1      0
# 3           3  SB-004  14010592  BC4201070 -1.222921    1      1
# 4           4  SB-005  14010759  BC4212692 -0.904990    1      1
#
#    Smoke_amount    Height    Weight       BMI       BSA occupation  \
# 0     -0.434404 -0.647980  1.561449  2.648742  1.031656         주부
# 1     -0.434404  0.231421 -0.371056 -0.622460 -0.224579        제조업
# 2      1.530757  1.487708  0.595196 -0.428835  0.899738         타일
# 3     -0.434404 -2.406781 -1.122586  0.582606 -1.532359         주부
# 4     -0.434404 -0.647980  0.917281  1.790708  0.558804        무응답
#
#        occupation_english                         address  \
# 0               housewife            경기도 시흥시 마유로 443번길 1
# 1  Manufacturing industry   경기 부천시 원미구 중동 무지개마을 1201-1602
# 2                    tile                 인천시 부평구 수변로 333
# 3               housewife                인천 서구 연희동 799-14
# 4             No response  경기 부천시 원미구 상3동 라일락마을 2333-1503
#
#                                      address_english Age_group BMI_category  \
# 0  1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...       NaN  Underweight
# 1  1201-1602, Rainbow Village in Middle East, Won...       <18          NaN
# 2                         333, Bupyeong -gu, Incheon       NaN          NaN
# 3              799-14, Yeonhui-dong, Seo-gu, Incheon       NaN  Underweight
# 4  2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...       NaN  Underweight
#
#   Smoking_intensity
# 0               NaN
# 1               NaN
# 2        Non-smoker
# 3               NaN
# 4               NaN

# %%
data=pd.read_csv("/content/data.csv")

# %%
data
# Out:
#      Unnamed: 0      ID     BCODE       UID1  Age Sex Smoke  Smoke_amount  \
# 0             0  SB-001  14631875  BC4386476   43   M    NS             0
# 1             1  SB-002  14010074  BC3298156   66   M    NS             0
# 2             2  SB-003  14221420  BC4165314   61   M    ES            20
# 3             3  SB-004  14010592  BC4201070   49   M    NS             0
# 4             4  SB-005  14010759  BC4212692   53   M    NS             0
# ..          ...     ...       ...        ...  ...  ..   ...           ...
# 109         109  SB-135  14000819  BC3296833   79   M    NS             0
# 110         110  SB-137  14000774  BC3300701   76   F    NS             0
# 111         111  SB-139  14000670  BC3334855   50   F    ES            20
# 112         112  SB-140  14000334  BC3309595   69   F    ES            15
# 113         113  SB-141  14000223  BC3294749   71   F    NS             0
#
#      Height  Weight        BMI       BSA occupation      occupation_english  \
# 0       156      76  31.229454  1.814754         주부               housewife
# 1       163      58  21.829952  1.620528        제조업  Manufacturing industry
# 2       173      67  22.386314  1.794358         타일                    tile
# 3       142      51  25.292601  1.418332         주부               housewife
# 4       156      70  28.763971  1.741647        무응답             No response
# ..      ...     ...        ...       ...        ...                     ...
# 109     163      67  25.217359  1.741726         무직            inoccupation
# 110     160      66  25.781250  1.712698         주부               housewife
# 111     162      64  24.386526  1.697056        건설업   Construction industry
# 112     170      72  24.913495  1.843909        건설업   Construction industry
# 113     162      73  27.815882  1.812457         기타                     etc
#
#                             address  \
# 0              경기도 시흥시 마유로 443번길 1
# 1     경기 부천시 원미구 중동 무지개마을 1201-1602
# 2                   인천시 부평구 수변로 333
# 3                  인천 서구 연희동 799-14
# 4    경기 부천시 원미구 상3동 라일락마을 2333-1503
# ..                              ...
# 109               부천시 원미구 도당동 137-4
# 110                  경기도 부천시 부흥로 71
# 111            부천시 원미구 중2동 그린타운 한신A
# 112                부천시 원미구 중3동 중흥마을
# 113                부천시 오정구 여월동 8-54
#
#                                        address_english
# 0    1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...
# 1    1201-1602, Rainbow Village in Middle East, Won...
# 2                           333, Bupyeong -gu, Incheon
# 3                799-14, Yeonhui-dong, Seo-gu, Incheon
# 4    2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...
# ..                                                 ...
# 109           137-4, Dodang-dong, Wonmi-gu, Bucheon-si
# 110         71, revival -ro, Bucheon -si, Gyeonggi -do
# 111                                          Hanshin A
# 112  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...
# 113            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si
#
# [114 rows x 16 columns]

# %%
# Example: Binning Age into groups
data['Age_group'] = pd.cut(data['Age'], bins=[0, 18, 30, 45, 60, 100], labels=['<18', '18-30', '30-45', '45-60', '60+'])

# Example: Binning BMI into categories
data['BMI_category'] = pd.cut(data['BMI'], bins=[0, 18.5, 24.9, 29.9, 100], labels=['Underweight', 'Normal', 'Overweight', 'Obese'])

# %%
data
# Out:
#      Unnamed: 0      ID     BCODE       UID1  Age Sex Smoke  Smoke_amount  \
# 0             0  SB-001  14631875  BC4386476   43   M    NS             0
# 1             1  SB-002  14010074  BC3298156   66   M    NS             0
# 2             2  SB-003  14221420  BC4165314   61   M    ES            20
# 3             3  SB-004  14010592  BC4201070   49   M    NS             0
# 4             4  SB-005  14010759  BC4212692   53   M    NS             0
# ..          ...     ...       ...        ...  ...  ..   ...           ...
# 109         109  SB-135  14000819  BC3296833   79   M    NS             0
# 110         110  SB-137  14000774  BC3300701   76   F    NS             0
# 111         111  SB-139  14000670  BC3334855   50   F    ES            20
# 112         112  SB-140  14000334  BC3309595   69   F    ES            15
# 113         113  SB-141  14000223  BC3294749   71   F    NS             0
#
#      Height  Weight        BMI       BSA occupation      occupation_english  \
# 0       156      76  31.229454  1.814754         주부               housewife
# 1       163      58  21.829952  1.620528        제조업  Manufacturing industry
# 2       173      67  22.386314  1.794358         타일                    tile
# 3       142      51  25.292601  1.418332         주부               housewife
# 4       156      70  28.763971  1.741647        무응답             No response
# ..      ...     ...        ...       ...        ...                     ...
# 109     163      67  25.217359  1.741726         무직            inoccupation
# 110     160      66  25.781250  1.712698         주부               housewife
# 111     162      64  24.386526  1.697056        건설업   Construction industry
# 112     170      72  24.913495  1.843909        건설업   Construction industry
# 113     162      73  27.815882  1.812457         기타                     etc
#
#                             address  \
# 0              경기도 시흥시 마유로 443번길 1
# 1     경기 부천시 원미구 중동 무지개마을 1201-1602
# 2                   인천시 부평구 수변로 333
# 3                  인천 서구 연희동 799-14
# 4    경기 부천시 원미구 상3동 라일락마을 2333-1503
# ..                              ...
# 109               부천시 원미구 도당동 137-4
# 110                  경기도 부천시 부흥로 71
# 111            부천시 원미구 중2동 그린타운 한신A
# 112                부천시 원미구 중3동 중흥마을
# 113                부천시 오정구 여월동 8-54
#
#                                        address_english Age_group BMI_category
# 0    1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...     30-45        Obese
# 1    1201-1602, Rainbow Village in Middle East, Won...       60+       Normal
# 2                           333, Bupyeong -gu, Incheon       60+       Normal
# 3                799-14, Yeonhui-dong, Seo-gu, Incheon     45-60   Overweight
# 4    2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...     45-60   Overweight
# ..                                                 ...       ...          ...
# 109           137-4, Dodang-dong, Wonmi-gu, Bucheon-si       60+   Overweight
# 110         71, revival -ro, Bucheon -si, Gyeonggi -do       60+   Overweight
# 111                                          Hanshin A     45-60       Normal
# 112  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...       60+   Overweight
# 113            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si       60+   Overweight
#
# [114 rows x 18 columns]

# %%
# Example: Creating Smoking Intensity feature
data['Smoking_intensity'] = pd.cut(data['Smoke_amount'], bins=[0,5, 20, 100], labels=['Non-smoker', 'Light smoker', 'Heavy smoker'],include_lowest=True)

# %%
data
# Out:
#      Unnamed: 0      ID     BCODE       UID1  Age Sex Smoke  Smoke_amount  \
# 0             0  SB-001  14631875  BC4386476   43   M    NS             0
# 1             1  SB-002  14010074  BC3298156   66   M    NS             0
# 2             2  SB-003  14221420  BC4165314   61   M    ES            20
# 3             3  SB-004  14010592  BC4201070   49   M    NS             0
# 4             4  SB-005  14010759  BC4212692   53   M    NS             0
# ..          ...     ...       ...        ...  ...  ..   ...           ...
# 109         109  SB-135  14000819  BC3296833   79   M    NS             0
# 110         110  SB-137  14000774  BC3300701   76   F    NS             0
# 111         111  SB-139  14000670  BC3334855   50   F    ES            20
# 112         112  SB-140  14000334  BC3309595   69   F    ES            15
# 113         113  SB-141  14000223  BC3294749   71   F    NS             0
#
#      Height  Weight        BMI       BSA occupation      occupation_english  \
# 0       156      76  31.229454  1.814754         주부               housewife
# 1       163      58  21.829952  1.620528        제조업  Manufacturing industry
# 2       173      67  22.386314  1.794358         타일                    tile
# 3       142      51  25.292601  1.418332         주부               housewife
# 4       156      70  28.763971  1.741647        무응답             No response
# ..      ...     ...        ...       ...        ...                     ...
# 109     163      67  25.217359  1.741726         무직            inoccupation
# 110     160      66  25.781250  1.712698         주부               housewife
# 111     162      64  24.386526  1.697056        건설업   Construction industry
# 112     170      72  24.913495  1.843909        건설업   Construction industry
# 113     162      73  27.815882  1.812457         기타                     etc
#
#                             address  \
# 0              경기도 시흥시 마유로 443번길 1
# 1     경기 부천시 원미구 중동 무지개마을 1201-1602
# 2                   인천시 부평구 수변로 333
# 3                  인천 서구 연희동 799-14
# 4    경기 부천시 원미구 상3동 라일락마을 2333-1503
# ..                              ...
# 109               부천시 원미구 도당동 137-4
# 110                  경기도 부천시 부흥로 71
# 111            부천시 원미구 중2동 그린타운 한신A
# 112                부천시 원미구 중3동 중흥마을
# 113                부천시 오정구 여월동 8-54
#
#                                        address_english Age_group BMI_category  \
# 0    1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...     30-45        Obese
# 1    1201-1602, Rainbow Village in Middle East, Won...       60+       Normal
# 2                           333, Bupyeong -gu, Incheon       60+       Normal
# 3                799-14, Yeonhui-dong, Seo-gu, Incheon     45-60   Overweight
# 4    2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...     45-60   Overweight
# ..                                                 ...       ...          ...
# 109           137-4, Dodang-dong, Wonmi-gu, Bucheon-si       60+   Overweight
# 110         71, revival -ro, Bucheon -si, Gyeonggi -do       60+   Overweight
# 111                                          Hanshin A     45-60       Normal
# 112  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...       60+   Overweight
# 113            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si       60+   Overweight
#
#     Smoking_intensity
# 0          Non-smoker
# 1          Non-smoker
# 2        Light smoker
# 3          Non-smoker
# 4          Non-smoker
# ..                ...
# 109        Non-smoker
# 110        Non-smoker
# 111      Light smoker
# 112      Light smoker
# 113        Non-smoker
#
# [114 rows x 19 columns]

# %%
print(df.dtypes)
# Out:
# Unnamed: 0               int64
# ID                      object
# BCODE                   object
# UID1                    object
# Age                    float64
# Sex                      int64
# Smoke                    int64
# Smoke_amount           float64
# Height                 float64
# Weight                 float64
# BMI                    float64
# BSA                    float64
# occupation              object
# occupation_english      object
# address                 object
# address_english         object
# Age_group             category
# BMI_category          category
# Smoking_intensity     category
# dtype: object

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy) (2.0)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'BCODE', 'UID1', 'Age', 'Sex', 'Smoke',
#        'Smoke_amount', 'Height', 'Weight', 'BMI', 'BSA', 'occupation',
#        'occupation_english', 'address', 'address_english', 'Age_group',
#        'BMI_category', 'Smoking_intensity'],
#       dtype='object')

# %%
from opencage.geocoder import OpenCageGeocode
import pandas as pd

# Replace 'your_opencage_api_key' with your actual API key
geocoder = OpenCageGeocode("2d14ae28e1654015899a680c301966b7")

def get_coordinates_opencage(address):
    result = geocoder.geocode(address)
    if result:
        return result[0]['geometry']['lat'], result[0]['geometry']['lng']
    else:
        return None, None

# Assuming you have a DataFrame 'data' with 'address_english' column
data[['latitude', 'longitude']] = data['address_english'].apply(lambda x: pd.Series(get_coordinates_opencage(x)))

# %%
from opencage.geocoder import OpenCageGeocode
import pandas as pd

# Replace 'your_opencage_api_key' with your actual API key
geocoder = OpenCageGeocode("2d14ae28e1654015899a680c301966b7")

def get_coordinates_opencage(address):
    result = geocoder.geocode(address)
    if result:
        latitude = result[0]['geometry']['lat']
        longitude = result[0]['geometry']['lng']
        formatted_address = result[0]['formatted']
        return latitude, longitude, formatted_address
    else:
        return None, None, None

# Assuming you have a DataFrame 'data' with 'address_english' column
data[['latitude', 'longitude', 'geocoded_address']] = data['address_english'].apply(lambda x: pd.Series(get_coordinates_opencage(x)))

# Create a new column 'address_match' to check if the geocoded address matches the original address
data['address_match'] = data.apply(lambda row: row['address_english'].lower() in row['geocoded_address'].lower() if row['geocoded_address'] else False, axis=1)

# Display the rows where the address doesn't match to review
discrepancies = data[data['address_match'] == False]
print("Addresses with discrepancies:")
print(discrepancies)
# Out:
# Addresses with discrepancies:
#      Unnamed: 0      ID     BCODE       UID1  Age Sex Smoke  Smoke_amount  \
# 0             0  SB-001  14631875  BC4386476   43   M    NS             0
# 1             1  SB-002  14010074  BC3298156   66   M    NS             0
# 2             2  SB-003  14221420  BC4165314   61   M    ES            20
# 3             3  SB-004  14010592  BC4201070   49   M    NS             0
# 4             4  SB-005  14010759  BC4212692   53   M    NS             0
# ..          ...     ...       ...        ...  ...  ..   ...           ...
# 109         109  SB-135  14000819  BC3296833   79   M    NS             0
# 110         110  SB-137  14000774  BC3300701   76   F    NS             0
# 111         111  SB-139  14000670  BC3334855   50   F    ES            20
# 112         112  SB-140  14000334  BC3309595   69   F    ES            15
# 113         113  SB-141  14000223  BC3294749   71   F    NS             0
#
#      Height  Weight  ...                                    address_english  \
# 0       156      76  ...  1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...
# 1       163      58  ...  1201-1602, Rainbow Village in Middle East, Won...
# 2       173      67  ...                         333, Bupyeong -gu, Incheon
# 3       142      51  ...              799-14, Yeonhui-dong, Seo-gu, Incheon
# 4       156      70  ...  2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...
# ..      ...     ...  ...                                                ...
# 109     163      67  ...           137-4, Dodang-dong, Wonmi-gu, Bucheon-si
# 110     160      66  ...         71, revival -ro, Bucheon -si, Gyeonggi -do
# 111     162      64  ...                                          Hanshin A
# 112     170      72  ...  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...
# 113     162      73  ...            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si
#
#      Age_group BMI_category Smoking_intensity   latitude   longitude altitude  \
# 0        30-45        Obese        Non-smoker  47.275410    8.489700    749.0
# 1          60+       Normal        Non-smoker  37.498890  126.783060     15.0
# 2          60+       Normal      Light smoker  37.474580  126.680240     10.0
# 3        45-60   Overweight        Non-smoker  37.548639  126.682664     38.0
# 4        45-60   Overweight        Non-smoker  37.498890  126.783060     15.0
# ..         ...          ...               ...        ...         ...      ...
# 109        60+   Overweight        Non-smoker  37.512130  126.785189     21.0
# 110        60+   Overweight        Non-smoker  37.498890  126.783060     15.0
# 111      45-60       Normal      Light smoker  34.621465  135.533049      8.0
# 112        60+   Overweight      Light smoker  37.498890  126.783060     15.0
# 113        60+   Overweight        Non-smoker  37.498890  126.783060     15.0
#
#     Altitude_Category                                   geocoded_address  \
# 0        Low Altitude     Aeugst am Albis, Bezirk Affoltern, Switzerland
# 1        Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# 2        Low Altitude  South Korea, Incheon, Gajwa 3(sam)-dong, Bangc...
# 3        Low Altitude                 Yeonhui-dong, Incheon, South Korea
# 4        Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# ..                ...                                                ...
# 109      Low Altitude  South Korea, Gyeonggi, Bucheon-si, Wonmi-gu, 1...
# 110      Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# 111      Low Altitude  Hanshin Expressway Route 14 Matsubara Line, Hi...
# 112      Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# 113      Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
#
#      address_match
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ..             ...
# 109          False
# 110          False
# 111          False
# 112          False
# 113          False
#
# [114 rows x 25 columns]

# %%
data.to_csv('data_with_latitude_altitude.csv', index=False)

# %%
import pandas as pd
import requests
import numpy as np


# Function to get altitude from Open-Meteo Elevation API (free and no API key required)
def get_altitude_open_meteo(latitude, longitude):
    # Check if latitude or longitude is NaN
    if np.isnan(latitude) or np.isnan(longitude):
        print("Skipping due to NaN values for latitude or longitude.")
        return None

    try:
        # Query the Open-Meteo API for elevation data
        url = f"https://api.open-meteo.com/v1/elevation?latitude={latitude}&longitude={longitude}"
        response = requests.get(url)

        # Check for a successful request
        if response.status_code == 200:
            elevation = response.json().get("elevation")

            # Check if elevation is a list and extract the first element if it is
            if isinstance(elevation, list) and len(elevation) > 0:
                elevation = elevation[0]

            # Ensure elevation is a single numeric value
            if isinstance(elevation, (int, float)):
                return elevation
            else:
                print(f"Unexpected data format for elevation: {elevation}")
                return None
        else:
            print(f"Error: Received status code {response.status_code}")
            print(f"URL: {url}")  # Print URL for debugging
            return None
    except Exception as e:
        print(f"Error retrieving altitude: {e}")
        return None

# Function to categorize altitude
def categorize_altitude(altitude):
    if altitude is None:
        return "Altitude not available"
    elif altitude > 2500:
        return "High Altitude"
    elif 1000 <= altitude <= 2500:
        return "Mid Altitude"
    else:
        return "Low Altitude"

# Apply the function to get altitude and categorize for each row in the DataFrame
data['altitude'] = data.apply(lambda row: get_altitude_open_meteo(row['latitude'], row['longitude']), axis=1)
data['Altitude_Category'] = data['altitude'].apply(categorize_altitude)

# Display the DataFrame with the new columns
print(data)

# Optionally, save the DataFrame with altitude and altitude category back to a new CSV file
data.to_csv('data_with_altitude.csv', index=False)
# Out:
# Skipping due to NaN values for latitude or longitude.
# Skipping due to NaN values for latitude or longitude.
# Skipping due to NaN values for latitude or longitude.
# Skipping due to NaN values for latitude or longitude.
# Skipping due to NaN values for latitude or longitude.
#      Unnamed: 0      ID     BCODE       UID1  Age Sex Smoke  Smoke_amount  \
# 0             0  SB-001  14631875  BC4386476   43   M    NS             0
# 1             1  SB-002  14010074  BC3298156   66   M    NS             0
# 2             2  SB-003  14221420  BC4165314   61   M    ES            20
# 3             3  SB-004  14010592  BC4201070   49   M    NS             0
# 4             4  SB-005  14010759  BC4212692   53   M    NS             0
# ..          ...     ...       ...        ...  ...  ..   ...           ...
# 109         109  SB-135  14000819  BC3296833   79   M    NS             0
# 110         110  SB-137  14000774  BC3300701   76   F    NS             0
# 111         111  SB-139  14000670  BC3334855   50   F    ES            20
# 112         112  SB-140  14000334  BC3309595   69   F    ES            15
# 113         113  SB-141  14000223  BC3294749   71   F    NS             0
#
#      Height  Weight  ...      occupation_english  \
# 0       156      76  ...               housewife
# 1       163      58  ...  Manufacturing industry
# 2       173      67  ...                    tile
# 3       142      51  ...               housewife
# 4       156      70  ...             No response
# ..      ...     ...  ...                     ...
# 109     163      67  ...            inoccupation
# 110     160      66  ...               housewife
# 111     162      64  ...   Construction industry
# 112     170      72  ...   Construction industry
# 113     162      73  ...                     etc
#
#                             address  \
# 0              경기도 시흥시 마유로 443번길 1
# 1     경기 부천시 원미구 중동 무지개마을 1201-1602
# 2                   인천시 부평구 수변로 333
# 3                  인천 서구 연희동 799-14
# 4    경기 부천시 원미구 상3동 라일락마을 2333-1503
# ..                              ...
# 109               부천시 원미구 도당동 137-4
# 110                  경기도 부천시 부흥로 71
# 111            부천시 원미구 중2동 그린타운 한신A
# 112                부천시 원미구 중3동 중흥마을
# 113                부천시 오정구 여월동 8-54
#
#                                        address_english Age_group BMI_category  \
# 0    1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...     30-45        Obese
# 1    1201-1602, Rainbow Village in Middle East, Won...       60+       Normal
# 2                           333, Bupyeong -gu, Incheon       60+       Normal
# 3                799-14, Yeonhui-dong, Seo-gu, Incheon     45-60   Overweight
# 4    2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...     45-60   Overweight
# ..                                                 ...       ...          ...
# 109           137-4, Dodang-dong, Wonmi-gu, Bucheon-si       60+   Overweight
# 110         71, revival -ro, Bucheon -si, Gyeonggi -do       60+   Overweight
# 111                                          Hanshin A     45-60       Normal
# 112  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...       60+   Overweight
# 113            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si       60+   Overweight
#
#     Smoking_intensity   latitude   longitude altitude  Altitude_Category
# 0          Non-smoker  47.275410    8.489700    749.0       Low Altitude
# 1          Non-smoker  37.498890  126.783060     15.0       Low Altitude
# 2        Light smoker  37.474580  126.680240     10.0       Low Altitude
# 3          Non-smoker  37.548639  126.682664     38.0       Low Altitude
# 4          Non-smoker  37.498890  126.783060     15.0       Low Altitude
# ..                ...        ...         ...      ...                ...
# 109        Non-smoker  37.512130  126.785189     21.0       Low Altitude
# 110        Non-smoker  37.498890  126.783060     15.0       Low Altitude
# 111      Light smoker  34.621465  135.533049      8.0       Low Altitude
# 112      Light smoker  37.498890  126.783060     15.0       Low Altitude
# 113        Non-smoker  37.498890  126.783060     15.0       Low Altitude
#
# [114 rows x 23 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'BCODE', 'UID1', 'Age', 'Sex', 'Smoke',
#        'Smoke_amount', 'Height', 'Weight', 'BMI', 'BSA', 'occupation',
#        'occupation_english', 'address', 'address_english', 'Age_group',
#        'BMI_category', 'Smoking_intensity', 'latitude', 'longitude'],
#       dtype='object')

# %%
# Out:
#      Unnamed: 0      ID     BCODE       UID1  Age Sex Smoke  Smoke_amount  \
# 0             0  SB-001  14631875  BC4386476   43   M    NS             0
# 1             1  SB-002  14010074  BC3298156   66   M    NS             0
# 2             2  SB-003  14221420  BC4165314   61   M    ES            20
# 3             3  SB-004  14010592  BC4201070   49   M    NS             0
# 4             4  SB-005  14010759  BC4212692   53   M    NS             0
# ..          ...     ...       ...        ...  ...  ..   ...           ...
# 109         109  SB-135  14000819  BC3296833   79   M    NS             0
# 110         110  SB-137  14000774  BC3300701   76   F    NS             0
# 111         111  SB-139  14000670  BC3334855   50   F    ES            20
# 112         112  SB-140  14000334  BC3309595   69   F    ES            15
# 113         113  SB-141  14000223  BC3294749   71   F    NS             0
#
#      Height  Weight  ...      occupation_english  \
# 0       156      76  ...               housewife
# 1       163      58  ...  Manufacturing industry
# 2       173      67  ...                    tile
# 3       142      51  ...               housewife
# 4       156      70  ...             No response
# ..      ...     ...  ...                     ...
# 109     163      67  ...            inoccupation
# 110     160      66  ...               housewife
# 111     162      64  ...   Construction industry
# 112     170      72  ...   Construction industry
# 113     162      73  ...                     etc
#
#                             address  \
# 0              경기도 시흥시 마유로 443번길 1
# 1     경기 부천시 원미구 중동 무지개마을 1201-1602
# 2                   인천시 부평구 수변로 333
# 3                  인천 서구 연희동 799-14
# 4    경기 부천시 원미구 상3동 라일락마을 2333-1503
# ..                              ...
# 109               부천시 원미구 도당동 137-4
# 110                  경기도 부천시 부흥로 71
# 111            부천시 원미구 중2동 그린타운 한신A
# 112                부천시 원미구 중3동 중흥마을
# 113                부천시 오정구 여월동 8-54
#
#                                        address_english Age_group BMI_category  \
# 0    1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...     30-45        Obese
# 1    1201-1602, Rainbow Village in Middle East, Won...       60+       Normal
# 2                           333, Bupyeong -gu, Incheon       60+       Normal
# 3                799-14, Yeonhui-dong, Seo-gu, Incheon     45-60   Overweight
# 4    2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...     45-60   Overweight
# ..                                                 ...       ...          ...
# 109           137-4, Dodang-dong, Wonmi-gu, Bucheon-si       60+   Overweight
# 110         71, revival -ro, Bucheon -si, Gyeonggi -do       60+   Overweight
# 111                                          Hanshin A     45-60       Normal
# 112  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...       60+   Overweight
# 113            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si       60+   Overweight
#
#     Smoking_intensity   latitude   longitude altitude  Altitude_Category
# 0          Non-smoker  47.275410    8.489700    749.0       Low Altitude
# 1          Non-smoker  37.498890  126.783060     15.0       Low Altitude
# 2        Light smoker  37.474580  126.680240     10.0       Low Altitude
# 3          Non-smoker  37.548639  126.682664     38.0       Low Altitude
# 4          Non-smoker  37.498890  126.783060     15.0       Low Altitude
# ..                ...        ...         ...      ...                ...
# 109        Non-smoker  37.512130  126.785189     21.0       Low Altitude
# 110        Non-smoker  37.498890  126.783060     15.0       Low Altitude
# 111      Light smoker  34.621465  135.533049      8.0       Low Altitude
# 112      Light smoker  37.498890  126.783060     15.0       Low Altitude
# 113        Non-smoker  37.498890  126.783060     15.0       Low Altitude
#
# [114 rows x 23 columns]

# %%
data=pd.read_csv("/content/data_with_latitude_altitude.csv")

# %%
data
# Out:
#      Unnamed: 0      ID     BCODE       UID1  Age Sex Smoke  Smoke_amount  \
# 0             0  SB-001  14631875  BC4386476   43   M    NS             0
# 1             1  SB-002  14010074  BC3298156   66   M    NS             0
# 2             2  SB-003  14221420  BC4165314   61   M    ES            20
# 3             3  SB-004  14010592  BC4201070   49   M    NS             0
# 4             4  SB-005  14010759  BC4212692   53   M    NS             0
# ..          ...     ...       ...        ...  ...  ..   ...           ...
# 109         109  SB-135  14000819  BC3296833   79   M    NS             0
# 110         110  SB-137  14000774  BC3300701   76   F    NS             0
# 111         111  SB-139  14000670  BC3334855   50   F    ES            20
# 112         112  SB-140  14000334  BC3309595   69   F    ES            15
# 113         113  SB-141  14000223  BC3294749   71   F    NS             0
#
#      Height  Weight  ...                                    address_english  \
# 0       156      76  ...  1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...
# 1       163      58  ...  1201-1602, Rainbow Village in Middle East, Won...
# 2       173      67  ...                         333, Bupyeong -gu, Incheon
# 3       142      51  ...              799-14, Yeonhui-dong, Seo-gu, Incheon
# 4       156      70  ...  2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...
# ..      ...     ...  ...                                                ...
# 109     163      67  ...           137-4, Dodang-dong, Wonmi-gu, Bucheon-si
# 110     160      66  ...         71, revival -ro, Bucheon -si, Gyeonggi -do
# 111     162      64  ...                                          Hanshin A
# 112     170      72  ...  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...
# 113     162      73  ...            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si
#
#      Age_group BMI_category Smoking_intensity   latitude   longitude altitude  \
# 0        30-45        Obese        Non-smoker  47.275410    8.489700    749.0
# 1          60+       Normal        Non-smoker  37.498890  126.783060     15.0
# 2          60+       Normal      Light smoker  37.474580  126.680240     10.0
# 3        45-60   Overweight        Non-smoker  37.548639  126.682664     38.0
# 4        45-60   Overweight        Non-smoker  37.498890  126.783060     15.0
# ..         ...          ...               ...        ...         ...      ...
# 109        60+   Overweight        Non-smoker  37.512130  126.785189     21.0
# 110        60+   Overweight        Non-smoker  37.498890  126.783060     15.0
# 111      45-60       Normal      Light smoker  34.621465  135.533049      8.0
# 112        60+   Overweight      Light smoker  37.498890  126.783060     15.0
# 113        60+   Overweight        Non-smoker  37.498890  126.783060     15.0
#
#     Altitude_Category                                   geocoded_address  \
# 0        Low Altitude     Aeugst am Albis, Bezirk Affoltern, Switzerland
# 1        Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# 2        Low Altitude  South Korea, Incheon, Gajwa 3(sam)-dong, Bangc...
# 3        Low Altitude                 Yeonhui-dong, Incheon, South Korea
# 4        Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# ..                ...                                                ...
# 109      Low Altitude  South Korea, Gyeonggi, Bucheon-si, Wonmi-gu, 1...
# 110      Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# 111      Low Altitude  Hanshin Expressway Route 14 Matsubara Line, Hi...
# 112      Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# 113      Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
#
#      address_match
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ..             ...
# 109          False
# 110          False
# 111          False
# 112          False
# 113          False
#
# [114 rows x 25 columns]

# %%
# Update address_match to True if 'South Korea' is in geocoded_address
data.loc[data['geocoded_address'].str.contains('South Korea', case=False, na=False), 'address_match'] = True

# %%
data
# Out:
#      Unnamed: 0      ID     BCODE       UID1  Age Sex Smoke  Smoke_amount  \
# 0             0  SB-001  14631875  BC4386476   43   M    NS             0
# 1             1  SB-002  14010074  BC3298156   66   M    NS             0
# 2             2  SB-003  14221420  BC4165314   61   M    ES            20
# 3             3  SB-004  14010592  BC4201070   49   M    NS             0
# 4             4  SB-005  14010759  BC4212692   53   M    NS             0
# ..          ...     ...       ...        ...  ...  ..   ...           ...
# 109         109  SB-135  14000819  BC3296833   79   M    NS             0
# 110         110  SB-137  14000774  BC3300701   76   F    NS             0
# 111         111  SB-139  14000670  BC3334855   50   F    ES            20
# 112         112  SB-140  14000334  BC3309595   69   F    ES            15
# 113         113  SB-141  14000223  BC3294749   71   F    NS             0
#
#      Height  Weight  ...                                    address_english  \
# 0       156      76  ...  1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...
# 1       163      58  ...  1201-1602, Rainbow Village in Middle East, Won...
# 2       173      67  ...                         333, Bupyeong -gu, Incheon
# 3       142      51  ...              799-14, Yeonhui-dong, Seo-gu, Incheon
# 4       156      70  ...  2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...
# ..      ...     ...  ...                                                ...
# 109     163      67  ...           137-4, Dodang-dong, Wonmi-gu, Bucheon-si
# 110     160      66  ...         71, revival -ro, Bucheon -si, Gyeonggi -do
# 111     162      64  ...                                          Hanshin A
# 112     170      72  ...  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...
# 113     162      73  ...            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si
#
#      Age_group BMI_category Smoking_intensity   latitude   longitude altitude  \
# 0        30-45        Obese        Non-smoker  47.275410    8.489700    749.0
# 1          60+       Normal        Non-smoker  37.498890  126.783060     15.0
# 2          60+       Normal      Light smoker  37.474580  126.680240     10.0
# 3        45-60   Overweight        Non-smoker  37.548639  126.682664     38.0
# 4        45-60   Overweight        Non-smoker  37.498890  126.783060     15.0
# ..         ...          ...               ...        ...         ...      ...
# 109        60+   Overweight        Non-smoker  37.512130  126.785189     21.0
# 110        60+   Overweight        Non-smoker  37.498890  126.783060     15.0
# 111      45-60       Normal      Light smoker  34.621465  135.533049      8.0
# 112        60+   Overweight      Light smoker  37.498890  126.783060     15.0
# 113        60+   Overweight        Non-smoker  37.498890  126.783060     15.0
#
#     Altitude_Category                                   geocoded_address  \
# 0        Low Altitude     Aeugst am Albis, Bezirk Affoltern, Switzerland
# 1        Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# 2        Low Altitude  South Korea, Incheon, Gajwa 3(sam)-dong, Bangc...
# 3        Low Altitude                 Yeonhui-dong, Incheon, South Korea
# 4        Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# ..                ...                                                ...
# 109      Low Altitude  South Korea, Gyeonggi, Bucheon-si, Wonmi-gu, 1...
# 110      Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# 111      Low Altitude  Hanshin Expressway Route 14 Matsubara Line, Hi...
# 112      Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# 113      Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
#
#      address_match
# 0            False
# 1             True
# 2             True
# 3             True
# 4             True
# ..             ...
# 109           True
# 110           True
# 111          False
# 112           True
# 113           True
#
# [114 rows x 25 columns]

# %%
data.to_csv('data_with_latitude_altitude.csv', index=False)

# %%
df=pd.read_csv("/content/data_with_latitude_altitude (1).csv")

# %%
df
# Out:
#      Unnamed: 0      ID     BCODE       UID1  Age Sex Smoke  Smoke_amount  \
# 0             0  SB-001  14631875  BC4386476   43   M    NS             0
# 1             1  SB-002  14010074  BC3298156   66   M    NS             0
# 2             2  SB-003  14221420  BC4165314   61   M    ES            20
# 3             3  SB-004  14010592  BC4201070   49   M    NS             0
# 4             4  SB-005  14010759  BC4212692   53   M    NS             0
# ..          ...     ...       ...        ...  ...  ..   ...           ...
# 109         109  SB-135  14000819  BC3296833   79   M    NS             0
# 110         110  SB-137  14000774  BC3300701   76   F    NS             0
# 111         111  SB-139  14000670  BC3334855   50   F    ES            20
# 112         112  SB-140  14000334  BC3309595   69   F    ES            15
# 113         113  SB-141  14000223  BC3294749   71   F    NS             0
#
#      Height  Weight  ...                                    address_english  \
# 0       156      76  ...  1 Mayu -ro 443beon -gil, Siheung -si, Gyeonggi...
# 1       163      58  ...  1201-1602, Rainbow Village in Middle East, Won...
# 2       173      67  ...                         333, Bupyeong -gu, Incheon
# 3       142      51  ...              799-14, Yeonhui-dong, Seo-gu, Incheon
# 4       156      70  ...  2333-1503, Sang3-dong, Wonmi-gu, Bucheon-si, G...
# ..      ...     ...  ...                                                ...
# 109     163      67  ...           137-4, Dodang-dong, Wonmi-gu, Bucheon-si
# 110     160      66  ...         71, revival -ro, Bucheon -si, Gyeonggi -do
# 111     162      64  ...                                          Hanshin A
# 112     170      72  ...  Jungheung Village, 3 -dong, Wonmi -gu, Bucheon...
# 113     162      73  ...            8-54 Yeowol-dong, Ojeong-gu, Bucheon-si
#
#      Age_group BMI_category Smoking_intensity   latitude   longitude altitude  \
# 0        30-45        Obese        Non-smoker  47.275410    8.489700    749.0
# 1          60+       Normal        Non-smoker  37.498890  126.783060     15.0
# 2          60+       Normal      Light smoker  37.474580  126.680240     10.0
# 3        45-60   Overweight        Non-smoker  37.548639  126.682664     38.0
# 4        45-60   Overweight        Non-smoker  37.498890  126.783060     15.0
# ..         ...          ...               ...        ...         ...      ...
# 109        60+   Overweight        Non-smoker  37.512130  126.785189     21.0
# 110        60+   Overweight        Non-smoker  37.498890  126.783060     15.0
# 111      45-60       Normal      Light smoker  34.621465  135.533049      8.0
# 112        60+   Overweight      Light smoker  37.498890  126.783060     15.0
# 113        60+   Overweight        Non-smoker  37.498890  126.783060     15.0
#
#     Altitude_Category                                   geocoded_address  \
# 0        Low Altitude     Aeugst am Albis, Bezirk Affoltern, Switzerland
# 1        Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# 2        Low Altitude  South Korea, Incheon, Gajwa 3(sam)-dong, Bangc...
# 3        Low Altitude                 Yeonhui-dong, Incheon, South Korea
# 4        Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# ..                ...                                                ...
# 109      Low Altitude  South Korea, Gyeonggi, Bucheon-si, Wonmi-gu, 1...
# 110      Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# 111      Low Altitude  Hanshin Expressway Route 14 Matsubara Line, Hi...
# 112      Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
# 113      Low Altitude               Bucheon-si, Gyeonggi-do, South Korea
#
#      address_match
# 0            False
# 1             True
# 2             True
# 3             True
# 4             True
# ..             ...
# 109           True
# 110           True
# 111          False
# 112           True
# 113           True
#
# [114 rows x 25 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0         Age  Smoke_amount      Height      Weight  \
# count  114.000000  114.000000    114.000000  114.000000  114.000000
# mean    56.500000   64.385965      4.421053  161.157895   61.456140
# std     33.052988   12.636868     10.222217    7.995108    9.355459
# min      0.000000   30.000000      0.000000  142.000000   40.000000
# 25%     28.250000   57.000000      0.000000  156.000000   54.000000
# 50%     56.500000   65.000000      0.000000  161.500000   61.000000
# 75%     84.750000   72.000000      0.750000  166.000000   68.000000
# max    113.000000   90.000000     60.000000  187.000000   83.000000
#
#               BMI         BSA    latitude   longitude    altitude
# count  114.000000  114.000000  109.000000  109.000000  109.000000
# mean    23.618534    1.655250   36.120302  121.864220   58.422018
# std      2.886096    0.155292    8.714061   23.528512  121.079274
# min     16.866251    1.299573  -34.922906    5.400000    7.000000
# 25%     21.734046    1.535278   37.444350  126.724025   15.000000
# 50%     23.624884    1.647388   37.498890  126.783060   20.000000
# 75%     25.276806    1.777755   37.517600  126.882120   43.000000
# max     32.830980    1.990812   47.275410  138.603014  749.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'BCODE', 'UID1', 'Age', 'Sex', 'Smoke',
#        'Smoke_amount', 'Height', 'Weight', 'BMI', 'BSA', 'occupation',
#        'occupation_english', 'address', 'address_english', 'Age_group',
#        'BMI_category', 'Smoking_intensity', 'latitude', 'longitude',
#        'altitude', 'Altitude_Category', 'geocoded_address', 'address_match'],
#       dtype='object')

# %%
import pandas as pd

# Define a function to handle outliers using IQR method
def handle_outliers(df, columns):
    for col in columns:
        # Calculate Q1 (25th percentile) and Q3 (75th percentile)
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1  # Interquartile Range

        # Define the bounds for outliers
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Count the number of outliers
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        print(f"Number of outliers in {col}: {outliers.shape[0]}")

        # Option 1: Remove outliers
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

        # Option 2: Alternatively, you can replace outliers with median
        # median_value = df[col].median()
        # df[col] = df[col].apply(lambda x: median_value if x < lower_bound or x > upper_bound else x)

    return df

# Specify the columns to check for outliers
numerical_columns = ['Age', 'Height', 'Weight', 'BMI', 'BSA', 'latitude', 'longitude', 'altitude']

# Handle outliers in the specified columns
df_cleaned = handle_outliers(df, numerical_columns)

# Display summary of the cleaned dataset
print("\nSummary after outlier handling:\n", df_cleaned.describe())
# Out:
# Number of outliers in Age: 3
# Number of outliers in Height: 1
# Number of outliers in Weight: 0
# Number of outliers in BMI: 2
# Number of outliers in BSA: 0
# Number of outliers in latitude: 25
# Number of outliers in longitude: 4
# Number of outliers in altitude: 6
#
# Summary after outlier handling:
#         Unnamed: 0        Age  Smoke_amount      Height     Weight        BMI  \
# count   69.000000  69.000000     69.000000   69.000000  69.000000  69.000000
# mean    60.971014  66.391304      4.014493  160.637681  61.072464  23.622385
# std     33.155148  10.918437     10.641888    8.364791   9.212075   2.792935
# min      1.000000  40.000000      0.000000  142.000000  40.000000  16.866251
# 25%     31.000000  60.000000      0.000000  155.000000  54.000000  21.799445
# 50%     66.000000  67.000000      0.000000  162.000000  60.000000  23.384354
# 75%     89.000000  75.000000      0.000000  166.000000  69.000000  25.292601
# max    113.000000  85.000000     60.000000  178.000000  79.000000  29.937595
#
#              BSA   latitude   longitude   altitude
# count  69.000000  69.000000   69.000000  69.000000
# mean    1.647581  37.493837  126.778339  20.362319
# std     0.156157   0.031205    0.076648   9.357242
# min     1.308094  37.403110  126.619540   8.000000
# 25%     1.520417  37.490122  126.723817  15.000000
# 50%     1.668333  37.498890  126.783060  16.000000
# 75%     1.783723  37.509710  126.785189  23.000000
# max     1.902849  37.567161  127.000560  47.000000

# %%
# Pie Chart for Sex Distribution
plt.figure(figsize=(8, 8))
df['Sex'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap='viridis')
plt.title('Sex Distribution')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df['Age_group'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Age Group Distribution')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='BMI_category', data=df)
plt.title('Distribution of BMI Categories')
plt.xlabel('BMI Category')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df['BMI_category'].value_counts().plot(kind='barh', color='salmon')
plt.title('Distribution of BMI Categories')
plt.xlabel('Count')
plt.ylabel('BMI Category')
plt.show()

# %%
age_smoke_mean = df.groupby('Age')['Smoke_amount'].mean()
plt.figure(figsize=(12, 6))
plt.plot(age_smoke_mean.index, age_smoke_mean.values, marker='o', linestyle='-')
plt.title('Average Smoke Amount by Age')
plt.xlabel('Age')
plt.ylabel('Average Smoke Amount')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hexbin(df['longitude'], df['latitude'], gridsize=30, cmap='Blues', mincnt=1)
plt.colorbar(label='Frequency')
plt.title('Geographical Hexbin Plot (latitude vs longitude)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.violinplot(x='Smoking_intensity', y='Age', data=df)
plt.title('Age Distribution across Smoking Intensity Levels')
plt.xlabel('Smoking Intensity')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.swarmplot(x='Sex', y='Height', data=df, hue='BMI_category', dodge=True)
plt.title('Height Distribution by Sex with BMI Category')
plt.xlabel('Sex')
plt.ylabel('Height')
plt.legend(title='BMI Category')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Smoke_amount', hue='Smoking_intensity', style='Smoking_intensity', data=df)
plt.title('Scatter Plot of Age vs Smoke Amount by Smoking Intensity')
plt.xlabel('Age')
plt.ylabel('Smoke Amount')
plt.legend(title='Smoking Intensity')
plt.show()
